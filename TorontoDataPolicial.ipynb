# %% [markdown]
# <a href="https://colab.research.google.com/github/brunoxti/MachineLearning/blob/main/TorontoDataPolicial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# K -Means

import pandas as pd
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans

# %%
from google.colab import files
uploaded = files.upload()

for fn in uploaded.keys():

  print('Usuário fez upload de arquivos de nome "{name}" com tamanho de {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-67cef3e0-a193-476b-84fe-97461635be76" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-67cef3e0-a193-476b-84fe-97461635be76">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
crime_data = pd.read_csv('MCI_2014_to_2017.csv', delimiter= ",", header=0)

# %%
crime_data.head()
# Out:
#            X          Y  Index_ event_unique_id            occurrencedate  \
# 0 -79.520401  43.768829   14601  GO-20142775022  2014-08-25T04:00:00.000Z
# 1 -79.580856  43.642574   14602  GO-20142870874  2014-08-25T04:00:00.000Z
# 2 -79.260445  43.762909   14603  GO-20142802386  2014-08-25T04:00:00.000Z
# 3 -79.367546  43.663208   14604  GO-20142777955  2014-08-25T04:00:00.000Z
# 4 -79.231758  43.776440   14605  GO-20142778699  2014-08-25T04:00:00.000Z
#
#                reporteddate premisetype  ucr_code  ucr_ext       offence  ...  \
# 0  2014-08-25T04:00:00.000Z     Outside      1430      100       Assault  ...
# 1  2014-09-08T04:00:00.000Z       House      2120      220  B&E W'Intent  ...
# 2  2014-08-29T04:00:00.000Z       House      1430      100       Assault  ...
# 3  2014-08-26T04:00:00.000Z  Commercial      2120      200           B&E  ...
# 4  2014-08-26T04:00:00.000Z       Other      2120      200           B&E  ...
#
# ...

# %%
crime_data.dtypes
# Out:
# X                      float64
# Y                      float64
# Index_                   int64
# event_unique_id         object
# occurrencedate          object
# reporteddate            object
# premisetype             object
# ucr_code                 int64
# ucr_ext                  int64
# offence                 object
# reportedyear             int64
# reportedmonth           object
# reportedday              int64
# reporteddayofyear        int64
# reporteddayofweek       object
# reportedhour             int64
# occurrenceyear         float64
# occurrencemonth         object
# occurrenceday          float64
# occurrencedayofyear    float64
# occurrencedayofweek     object
# occurrencehour           int64
# MCI                     object
# Division                object
# Hood_ID                  int64
# Neighbourhood           object
# Lat                    float64
# Long                   float64
# FID                      int64
# dtype: object

# %%
crime_data[crime_data.X != crime_data.Long].head()
# Out:
#             X          Y  Index_ event_unique_id            occurrencedate  \
# 2  -79.260445  43.762909   14603  GO-20142802386  2014-08-25T04:00:00.000Z
# 3  -79.367546  43.663208   14604  GO-20142777955  2014-08-25T04:00:00.000Z
# 7  -79.382530  43.705540   14608  GO-20142779486  2014-08-25T04:00:00.000Z
# 9  -79.344650  43.764641   14610  GO-20142910587  2014-09-14T04:00:00.000Z
# 15 -79.343803  43.685032   14616  GO-20142906993  2014-09-14T04:00:00.000Z
#
#                 reporteddate premisetype  ucr_code  ucr_ext  offence  ...  \
# 2   2014-08-29T04:00:00.000Z       House      1430      100  Assault  ...
# 3   2014-08-26T04:00:00.000Z  Commercial      2120      200      B&E  ...
# 7   2014-08-26T04:00:00.000Z       House      2120      200      B&E  ...
# 9   2014-09-14T04:00:00.000Z   Apartment      1430      100  Assault  ...
# 15  2014-09-14T04:00:00.000Z       House      2120      200      B&E  ...
#
# ...

# %%
print(crime_data.X[2])
print(crime_data.Long[2])

# %%
crime_data.drop(['Index_','event_unique_id', 'X', 'Y', 'ucr_code', 'ucr_ext', 'FID', 'Neighbourhood'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-a3bf20c25d8e> in <module>
# ----> 1 crime_data.drop(['Index_','event_unique_id', 'X', 'Y', 'ucr_code', 'ucr_ext', 'FID', 'Neighbourhood'], axis=1, inplace=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ...

# %%
crime_data.head()
# Out:
#              occurrencedate              reporteddate premisetype  \
# 0  2014-08-25T04:00:00.000Z  2014-08-25T04:00:00.000Z     Outside
# 1  2014-08-25T04:00:00.000Z  2014-09-08T04:00:00.000Z       House
# 2  2014-08-25T04:00:00.000Z  2014-08-29T04:00:00.000Z       House
# 3  2014-08-25T04:00:00.000Z  2014-08-26T04:00:00.000Z  Commercial
# 4  2014-08-25T04:00:00.000Z  2014-08-26T04:00:00.000Z       Other
#
#         offence  reportedyear reportedmonth  reportedday  reporteddayofyear  \
# 0       Assault          2014        August           25                237
# 1  B&E W'Intent          2014     September            8                251
# 2       Assault          2014        August           29                241
# 3           B&E          2014        August           26                238
# 4           B&E          2014        August           26                238
#
#   reporteddayofweek  reportedhour  ...  occurrencemonth occurrenceday  \
# ...

# %%
occurrencedate_list = crime_data.occurrencedate.str.split('T').tolist()
reporteddate_list = crime_data.reporteddate.str.split('T').tolist()

for i in range(len(occurrencedate_list)):
  occurrencedate_list[i] = occurrencedate_list[i][0]

for i in range(len(reporteddate_list)):
  reporteddate_list[i] = reporteddate_list[i][0]

  crime_data['occurrencedate'] = occurrencedate_list
  crime_data['reporteddate'] = reporteddate_list

  crime_data.occurrencedate = pd.to_datetime(crime_data.occurrencedate)
  crime_data.reporteddate = pd.to_datetime(crime_data.reporteddate)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-97b436f1ec68> in <module>
# ----> 1 occurrencedate_list = crime_data.occurrencedate.str.split('T').tolist()
#       2 reporteddate_list = crime_data.reporteddate.str.split('T').tolist()
#       3
#       4 for i in range(len(occurrencedate_list)):
#       5   occurrencedate_list[i] = occurrencedate_list[i][0]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# ...

# %%
crime_data.drop(['reportedyear','','','','','','',''],axis=1, inplance=True)

# %%
crime_data.dtypes

# %%
crime_data.premisetype = crime_data.premisetype.astype('category', error='raise')
crime_data.offence = crime_data.offence.astype('category', error='raise')
crime_data.MCI = crime_data.MCI.astype('category', error='raise')
crime_data.reporteddayofweek = crime_data.reporteddayofweek.astype('category', error='raise')
crime_data.reporteddayofweek = crime_data.reporteddayofweek.str.rstrip().astype('category', error='raise')
crime_data.Division = crime_data.Division.astype('category', error='raise')

# %%
def doKMeans(data, n_clusters):
  fig = plt.figure()
  ax = fig.add_subplot(111)
  ax.scatter(data.Long. data.Lat, marker='.', c='blue')

  data = data.loc[:, ['Long, Lat']]

  model = KMeans(n_clusters=n_clusters)
  model.fit(data)

  centroids = model.cluster_centers_
  print(centroids)

  ax.scatter(centroids[:,0], centroids[:,1], marker='x', c='red')
  plt.show()

# %%
break_enter = crime_data[(crime_data.MCI == 'Break and Ener') & (crime_data.premisetype == 'Apartment')]

break_enter.reset_index(inplance=True, drop=True)

# %%
break_enter
